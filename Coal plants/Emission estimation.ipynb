# %% [markdown]
# # Looking at the statistics of the coal plants in Pakistan and india

# %%
import pandas as pd

import matplotlib.pyplot as plt

import geopandas as gpd

# %%
def estimate_emissions_from_excel(file_path, sheet_name, countries_column, capacity_column):
    """
    This function reads data from an Excel file, estimates emissions for each pollutant,
    and returns a DataFrame with the original data and additional columns for emissions.

    Args:
        file_path (str): Path to the Excel file containing the data.
        sheet_name (str): Name of the sheet containing the data.
        countries_column (str): Name of the column containing country names.
        capacity_column (str): Name of the column containing capacity data.

    Returns:
        pandas.DataFrame: DataFrame containing the original data and additional columns
                          for emissions of each pollutant.
    """
    # Read data from Excel file
    df = pd.read_excel(file_path, sheet_name=sheet_name)

    # Filter data for specific countries
    countries_list = ["Pakistan", "India", "Bangladesh"]
    if countries_column not in df.columns:
        raise ValueError(f"Column '{countries_column}' not found in the DataFrame.")
    df_igp = df[df[countries_column].isin(countries_list)].copy()

    # Calculate daily production (KW)
    df_igp['daily_production(KW)'] = df_igp[capacity_column] * 24 * 1000 * 365  # Annual production

    # Emission factors (g/kWh)
    avg_NOx = (4.22 + 4.38) / 2
    avg_SO2 = 7.20
    avg_PM10 = (0.29 + 0.45) / 2
    avg_PM25 = (0.16 + 0.22) / 2

    # Convert emissions from grams to tonnes
    df_igp['NOx_tonnes_per_KW/annum'] = df_igp['daily_production(KW)'] * avg_NOx / 1e6
    df_igp['SO2_tonnes_per_KW/annum'] = df_igp['daily_production(KW)'] * avg_SO2 / 1e6
    df_igp['PM10_tonnes_per_KW/annum'] = df_igp['daily_production(KW)'] * avg_PM10 / 1e6
    df_igp['PM25_tonnes_per_KW/annum'] = df_igp['daily_production(KW)'] * avg_PM25 / 1e6

    return df_igp

# %%
# you will have to define the path of your own file

file_path = r"D:\ERASMUS\France_Sem3\side projects\APAD_oxford\Global-Coal-Plant-Tracker-July-2023.xlsx"

sheet_name = "Units"  # Update with your sheet name if different

countries_column = "Country"  # Name of the column containing country names

capacity_column = "Capacity (MW)"  # Name of the column containing capacity data

df_with_emissions = estimate_emissions_from_excel(file_path, sheet_name, countries_column, capacity_column)
# Out:
# c:\Users\Khizer Zakir\anaconda3\envs\myenv\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df_with_emissions.head()
# Out:
#     GEM unit/phase ID GEM location ID     Country  \
# 148           G112681         L100059  Bangladesh
# 149           G101511         L100060  Bangladesh
# 150           G101512         L100060  Bangladesh
# 151           G100598         L100079  Bangladesh
# 152           G100599         L100079  Bangladesh
#
#                                               Wiki URL  \
# 148  https://www.gem.wiki/Banshkhali_power_station_...
# 149  https://www.gem.wiki/Banshkhali_power_station_...
# 150  https://www.gem.wiki/Banshkhali_power_station_...
# 151     https://www.gem.wiki/Barapukuria_power_station
# 152     https://www.gem.wiki/Barapukuria_power_station
#
#                              Plant name Unit name Plant name (local)  \
# 148  Banshkhali power station (Beximco)       NaN                NaN
# 149   Banshkhali power station (S Alam)    Unit 1                NaN
# 150   Banshkhali power station (S Alam)    Unit 2                NaN
# 151           Barapukuria power station    Unit 1                NaN
# 152           Barapukuria power station    Unit 2                NaN
#
#                                     Plant name (other)  \
# 148                                                NaN
# 149  Banskhali S. Alam power station, Chattogram po...
# 150  Banskhali S. Alam power station, Chattogram po...
# 151                                       বড়পুকুরিয়া
# 152                                       বড়পুকুরিয়া
#
#                                                  Owner  \
# 148        Power Construction Corporation of China Ltd
# 149  S Alam Group [70.0%]; Shandong Electric Power ...
# 150  S Alam Group [70.0%]; Shandong Electric Power ...
# 151                 Bangladesh Power Development Board
# 152                 Bangladesh Power Development Board
#
#                                                 Parent  ...  \
# 148        Power Construction Corporation of China Ltd  ...
# 149  S Alam Group [70.0%]; Shandong Electric Power ...  ...
# 150  S Alam Group [70.0%]; Shandong Electric Power ...  ...
# 151                 Bangladesh Power Development Board  ...
# 152                 Bangladesh Power Development Board  ...
#
#      Emission factor (kg of CO2 per TJ) Capacity factor  \
# 148                               96100            0.53
# 149                               96100            0.53
# 150                               96100            0.53
# 151                               94600            0.53
# 152                               94600            0.53
#
#      Annual CO2 (million tonnes / annum)  Lifetime CO2  \
# 148                                  2.7         106.9
# 149                                  2.6         104.5
# 150                                  2.6         104.5
# 151                                  0.7          15.1
# 152                                  0.7          15.1
#
#      Remaining plant lifetime (years) daily_production(KW)  \
# 148                                40         5.781600e+09
# 149                                40         5.781600e+09
# 150                                40         5.781600e+09
# 151                                23         1.095000e+09
# 152                                23         1.095000e+09
#
#     NOx_tonnes_per_KW/annum SO2_tonnes_per_KW/annum PM10_tonnes_per_KW/annum  \
# 148                24860.88                41627.52                 2139.192
# 149                24860.88                41627.52                 2139.192
# 150                24860.88                41627.52                 2139.192
# 151                 4708.50                 7884.00                  405.150
# 152                 4708.50                 7884.00                  405.150
#
#     PM25_tonnes_per_KW/annum
# 148                 1098.504
# 149                 1098.504
# 150                 1098.504
# 151                  208.050
# 152                  208.050
#
# [5 rows x 44 columns]

# %%
# group by country and plot the emissions
# Group by country and sum the emissions

df_grouped = df_with_emissions.groupby('Country').sum()

# Plot the emissions for each country
df_grouped.plot(kind='bar',
                 y=['NOx_tonnes_per_KW/annum',
                     'SO2_tonnes_per_KW/annum',
                       'PM10_tonnes_per_KW/annum',
                         'PM25_tonnes_per_KW/annum'],
                           figsize=(10, 6))
plt.title('Emissions from Coal Power Plants in Pakistan, India, and Bangladesh')
plt.ylabel('Emissions (tonnes)')
plt.xlabel('Country')
plt.xticks(rotation=0)
plt.legend(title='Pollutant')
plt.show()

# %%
# export as shapefile

# Create a GeoDataFrame from the DataFrame

gdf = gpd.GeoDataFrame(df_with_emissions,
                        geometry=gpd.points_from_xy(df_with_emissions.Longitude,
                                                     df_with_emissions.Latitude)
                                                     )
gdf.crs = "EPSG:4326"
#plot the GeoDataFrame to check if it is correct
gdf.plot()

# Save the GeoDataFrame to a shapefile
gdf.to_file("coal_power_plants_emissions.shp")
# Out:
# C:\Users\Khizer Zakir\AppData\Local\Temp\ipykernel_8532\4103894356.py:14: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf.to_file("coal_power_plants_emissions.shp")

# %%
import pandas as pd
import geopandas as gpd

def export_shapefile_from_excel(file_path, sheet_name, countries_column, countries_list, output_shapefile):
    """
    Reads an Excel file, filters it based on specified countries, and exports the filtered data as a shapefile.

    Parameters:
        file_path (str): Path to the Excel file.
        sheet_name (str): Name of the sheet in the Excel file.
        countries_column (str): Name of the column containing country names.
        countries_list (list of str): List of countries to filter the data for.
        output_shapefile (str): Path to save the output shapefile.

    Returns:
        GeoDataFrame: Filtered data as a GeoDataFrame.
    """
    # Read data from Excel file
    df = pd.read_excel(file_path, sheet_name=sheet_name)

    # Check if countries_column exists in DataFrame
    if countries_column not in df.columns:
        raise ValueError(f"Column '{countries_column}' not found in the DataFrame.")

    # Filter data for specific countries
    df_filtered = df[df[countries_column].isin(countries_list)].copy()

    # Create a GeoDataFrame from the DataFrame
    gdf = gpd.GeoDataFrame(df_filtered,
                            geometry=gpd.points_from_xy(df_filtered.Longitude, df_filtered.Latitude))
    gdf.crs = "EPSG:4326"  # Set the CRS to WGS84
    gdf.plot()

    # Save the GeoDataFrame to a shapefile
    gdf.to_file(output_shapefile)

    return gdf

# %%
# Read the Excel file
file_path = r"D:\ERASMUS\France_Sem3\side projects\APAD_oxford\Climate_Trace\paper_and_pulp.xlsx"

sheet_name = "Sheet1"  # Update with your sheet name if different

countries_column = "country"
countries_list = ["PAKISTAN", "INDIA", "BANGLADESH"]
output_shapefile = "paper_pulp.shp"

export_shapefile_from_excel(file_path, sheet_name, countries_column, countries_list, output_shapefile)
# Out:
# C:\Users\Khizer Zakir\AppData\Local\Temp\ipykernel_8532\335873547.py:35: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf.to_file(output_shapefile)
#       S.No                                         plant name  \
# 78      38                   Sonali Paper and Board Mills Ltd
# 79     266            Hussain Pulp, Paper and Board Mills Ltd
# 80     632  Hussain Pulp, Paper and Board Mills Ltd, Enaye...
# 81     658  Karnaphuli Paper Mills Ltd, BCIC Bangladesh Ch...
# 82     693                  NBPM North Bengal Paper Mills Ltd
# ...    ...                                                ...
# 3250  2855                      Karachi Paper and Board Mills
# 3251  2856                                   Lucky Paper Mill
# 3252  2857   Bin Qasim Packages Ltd, Karachi Corrugating Unit
# 3253  2859                                      Pioneer Board
# 3254  2860                            Pakistan Paper Products
#
#                                            full_address  \
# 78    Rajuk Bhaban, Rajuk Avenue, Dhaka 1000, Bangla...
# 79      Tejgaon Industrial Area, Dhaka 1208, Bangladesh
# 80                         Narayanganj 1400, Bangladesh
# 81               92 Strand Road, Chittagong, Bangladesh
# 82    North Bengal Paper Mills, Ishurdi 6620, Bangla...
# ...                                                 ...
# 3250  R5V3+83R, Shah Muhammad Rd, Sector 27 Landhi T...
# 3251         973G+H34, Kotri, Jamshoro, Sindh, Pakistan
# 3252  6 6, 1, Sector 28 Landhi Town, Karachi, Karach...
# 3253          24 Km Multan Rd, Lahore, Punjab, Pakistan
# 3254  Ghani Chorangi, D-58 Estate Ave, Sindh Industr...
#
#                                            city     country  \
# 78                                        DHAKA  BANGLADESH
# 79                                        DHAKA  BANGLADESH
# 80                                  NARAYANGANJ  BANGLADESH
# 81                                   CHITTAGONG  BANGLADESH
# 82                                       PAKSEY  BANGLADESH
# ...                                         ...         ...
# 3250  Karachi Paper & Board Mills (Pvt) Limited    PAKISTAN
# 3251                           Lucky Paper Mill    PAKISTAN
# 3252                                    KARACHI    PAKISTAN
# 3253                                     LAHORE    PAKISTAN
# 3254                  Pakistan Paper Products\n    PAKISTAN
#
#      Organization_Subcity Organization_City iso3 region  sub_region  ...  \
# 78                  DHAKA        BANGLADESH  BGD   Asia  South Asia  ...
# 79                  DHAKA        BANGLADESH  BGD   Asia  South Asia  ...
# 80            NARAYANGANJ        BANGLADESH  BGD   Asia  South Asia  ...
# 81             CHITTAGONG        BANGLADESH  BGD   Asia  South Asia  ...
# 82                 PAKSEY        BANGLADESH  BGD   Asia  South Asia  ...
# ...                   ...               ...  ...    ...         ...  ...
# 3250                  NaN               NaN  PAK    NaN         NaN  ...
# 3251                  NaN               NaN  PAK    NaN         NaN  ...
# 3252                  NaN               NaN  PAK    NaN         NaN  ...
# 3253                  NaN               NaN  PAK    NaN         NaN  ...
# 3254                  NaN               NaN  PAK    NaN         NaN  ...
#
#                                           sbert_results  sbert_LEI  \
# 78          [('Sonali Paper and Board Mills Ltd', 1.0)]        NaN
# 79    [('HUSSAIN PULP & PAPER MILLS LTD', 0.97764372...        NaN
# 80    [('HUSSAIN PULP & PAPER MILLS LTD', 0.86933821...        NaN
# 81    [('KARNAPHULI PAPER MILLS LTD', 0.861276745796...        NaN
# 82    [('North Bengal Paper Mills', 0.84794795513153...        NaN
# ...                                                 ...        ...
# 3250                                                NaN        NaN
# 3251                                                NaN        NaN
# 3252                                                NaN        NaN
# 3253                                                NaN        NaN
# 3254                                                NaN        NaN
#
#       sbert_PERMID_ID                          sbert_HeadquartersAddress  \
# 78       4.295941e+09  51, Central Road\nDhanmondi\nDHAKA\n1205\nBang...
# 79       4.296781e+09                                       Bangladesh\n
# 80       4.296781e+09                                       Bangladesh\n
# 81       4.296056e+09                                       Bangladesh\n
# 82       5.000959e+09                                       Bangladesh\n
# ...               ...                                                ...
# 3250              NaN                                                NaN
# 3251              NaN                                                NaN
# 3252              NaN                                                NaN
# 3253              NaN                                                NaN
# 3254              NaN                                                NaN
#
#         sbert_OrganizationPrimaryQuote        Quote_Name Quote_PERMID_ID  \
# 78    https://permid.org/1-55838855105  SONALI PAPER ORD    5.583886e+10
# 79                                 NaN               NaN             NaN
# 80                                 NaN               NaN             NaN
# 81                                 NaN               NaN             NaN
# 82                                 NaN               NaN             NaN
# ...                                ...               ...             ...
# 3250                               NaN               NaN             NaN
# 3251                               NaN               NaN             NaN
# 3252                               NaN               NaN             NaN
# 3253                               NaN               NaN             NaN
# 3254                               NaN               NaN             NaN
#
#       Quote_hasExchangeCode  Quote_hasExchangeTicker  \
# 78                      DSE               SONALIPAPR
# 79                      NaN                      NaN
# 80                      NaN                      NaN
# 81                      NaN                      NaN
# 82                      NaN                      NaN
# ...                     ...                      ...
# 3250                    NaN                      NaN
# 3251                    NaN                      NaN
# 3252                    NaN                      NaN
# 3253                    NaN                      NaN
# 3254                    NaN                      NaN
#
#                        geometry
# 78    POINT (90.41589 23.72633)
# 79    POINT (90.40545 23.76573)
# 80    POINT (90.49561 23.61008)
# 81    POINT (91.81755 22.32149)
# 82    POINT (89.05197 24.08081)
# ...                         ...
# 3250  POINT (67.15272 24.84334)
# 3251  POINT (68.27509 25.35425)
# 3252  POINT (67.17163 24.84639)
# 3253  POINT (74.14581 31.39628)
# 3254  POINT (66.99123 24.90031)
#
# [212 rows x 60 columns]
